# %% [markdown]
# Esercizio 01.1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

M=100000              
N=100                 
L=int(M/N)            
x = np.arange(N) 

sum_prog, err_prog = np.loadtxt("1.1.txt", usecols=(0,1), delimiter=' ', unpack='true')

x*=L 
plt.errorbar(x,sum_prog-0.5,yerr=err_prog)
plt.xlabel('#throws')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()

# %%
summ, err = np.loadtxt("1.2.txt", usecols=(0,1), delimiter=' ', unpack='true')

plt.errorbar(x,summ-1/12,yerr=err)
plt.xlabel('#throws')
plt.ylabel('<(r-0.5)^2>-1/2')
plt.grid(True)
plt.show()

# %%
j, chi = np.loadtxt("1.3.txt", usecols=(0,1), delimiter=' ', unpack='true')

plt.plot(j, chi, '-', label='Chi2')
plt.xlabel('x')
plt.ylabel('Chi2')
plt.legend()

plt.show()

# %% [markdown]
# Esercizio 2

# %%
one, two, ten, hund = np.loadtxt("unif.txt", usecols=(0,1,2,3), delimiter=' ', unpack='true')

n_bins = 100
n, bins, patches = plt.hist(one, n_bins, range=(0,1))

plt.xlabel('Sn')
plt.ylabel('Probability')
plt.title('Histogram of uniform distribution')
plt.grid(True)

plt.figure()
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('The same histogram ... but normalized')
n, bins, patches = plt.hist(two, n_bins, density=True, facecolor='g', range=(35,165))
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_5181/4158629667.py in <module>
# ----> 1 one, two, ten, hund = np.loadtxt("unif.txt", usecols=(0,1,2,3), delimiter=' ', unpack='true')
#       2
#       3 n_bins = 100
#       4 n, bins, patches = plt.hist(one, n_bins, range=(0,1))
#       5
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# --> 194     return ds.open(path, mode, encoding=encoding, newline=newline)
#     195
#     196
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     529                                       encoding=encoding, newline=newline)
#     530         else:
# --> 531             raise IOError("%s not found." % path)
#     532
#     533
#
# OSError: unif.txt not found.

# %% [markdown]
# Esercizio 3

# %%
pi, err_prog = np.loadtxt("pi.txt", usecols=(0,1), delimiter=' ', unpack='true')

N=100                        
x = np.arange(N) 

plt.errorbar(x,pi,yerr=err_prog)
plt.xlabel('#blocks')
plt.ylabel('pi')
plt.grid(True)
plt.show()
